# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/My-first/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Login Authentication System
#
# Problem Statement
# Develop a login system for Digital Dreams internal use.

# %%
# Predefined credentials
username = "dd_admin"
password = "dd@2025"

# User input
u = input("Enter Username: ")
p = input("Enter Password: ")

# Validation
if u == username and p == password:
    print("Login Successful")
else:
    print("Access Denied")
# Out:
# Enter Username: dd_admin
# Enter Password: dd@2025
# Login Successful
